# %% [markdown]
# ### Appendix K: Failed Labeling Attempts

# %%
# !pip install easyocr --quiet

# %%
import easyocr
reader = easyocr.Reader(['en'])

# %%
image_file = "hw_images/Abstractions-1.jpg"
plt.imshow(cv2.imread(image_file))
plt.show()

result = reader.readtext(image_file)
for bbox, text, confidence in result:
    print(f"Detected: {text} with confidence {confidence}")
# Out:
# Detected: TTw with confidence 0.11078476830666431
# Detected: idea with confidence 0.5314799547195435
# Detected: o p with confidence 0.3538295616205973
# Detected: 0 bs hractiom with confidence 0.23871559099937797
# Detected: T< with confidence 0.5286687293480736
# Detected: t with confidence 0.9432295350289941
# Detected: ~ke with confidence 0.3547123459567194
# Detected: aWoy with confidence 0.17144906520843506
# Detected: Wory with confidence 0.4098958671092987
# Detected: B bou & with confidence 0.20102689567537324
# Detected: Somelai-] with confidence 0.21754079562184417
# Detected: Wwks _ with confidence 0.32741434871498454
# Detected: It with confidence 0.1663694244647575
# Detected: i$ with confidence 0.4802738690391076
# Detected: 0 with confidence 0.9974025687163
# Detected: tio ^ with confidence 0.36017190234765073
# Detected: o f with confidence 0.18115045130252838
# Detected: much with confidence 0.4838031232357025
# Detected: mov e with confidence 0.42143655994822354
# ...

# %%
# %pip install pytesseract --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
import pytesseract

# Load image
image_path = "./hw_images/Abstractions-1.jpg"
img = Image.open(image_path)

plt.imshow(cv2.imread(image_path))
plt.show()

# Extract text
text = pytesseract.image_to_string(img)  # '--psm 10' assumes single characters
print(f"Recognized text: {text}")
# Out:
# Python(5829) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Recognized text: Tha Theo of oo ¢ rackton mw doke
# BWOY A Wen loot rove Somethira wks .
#
# Tk is 0 simpli fico. tion of something much
# move tompli cated Xhat vS gov on under the
#
# Couev s*
# To Law of leaky abetractions :
#
# A\\ Non- Kevwia\ absheactions, te SOM? degree,
# are leaky.
#
# Comin oy
#
# Coma bkimes kings | hronk- You did no thin g
# Wiong, you Polleug ad ‘the stops, yer they brook.
# Thon you hove to Keae OW oY Khe als bractions
# ond
